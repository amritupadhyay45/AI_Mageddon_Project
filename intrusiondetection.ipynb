# %%
# importing required libraries
import numpy as np
import pandas as pd



import numpy as np
import pandas as pd
# Out:
# Collecting liac-arff
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: liac-arff
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11716 sha256=36eb37711f0f71e1477a879ee93df7f26d59d40e6a1cfbc7d15d9d6649ee295b
#   Stored in directory: /root/.cache/pip/wheels/00/23/31/5e562fce1f95aabe57f2a7320d07433ba1cd152bcde2f6a002
# Successfully built liac-arff
# Installing collected packages: liac-arff
# Successfully installed liac-arff-2.5.0

# %%
# saving and loading trained model
import pickle
from os import path

# %%
# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
# importing library for plotting
import matplotlib.pyplot as plt

# %%
# importing library for support vector machine classifier
from sklearn.svm import SVC

# %%
# importing library for K-neares-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier

# %%
# importing library for Linear Discriminant Analysis Model
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
# importing library for Quadratic Discriminant Analysis Model
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

from keras.layers import Dense
from keras.models import Sequential
from keras.models import model_from_json

from keras.layers import LSTM
from keras.layers import Input
from keras.models import Model

# %%
# dataset doesn't have column names, so we have to provide it
col_names = ["duration","protocol_type","service","flag","src_bytes",
    "dst_bytes","land","wrong_fragment","urgent","hot","num_failed_logins",
    "logged_in","num_compromised","root_shell","su_attempted","num_root",
    "num_file_creations","num_shells","num_access_files","num_outbound_cmds",
    "is_host_login","is_guest_login","count","srv_count","serror_rate",
    "srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate",
    "diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count",
    "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
    "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate",
    "dst_host_rerror_rate","dst_host_srv_rerror_rate","label","difficulty_level"]

# %%
data = pd.read_csv('/content/KDDTest+.txt',header=None, names=col_names)

# %%
data
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0                   0       0    0  ...                    0.04
# 1                   0       0    0  ...                    0.00
# 2                   0       0    0  ...                    0.61
# 3                   0       0    0  ...                    1.00
# 4                   0       0    0  ...                    0.31
# ...               ...     ...  ...  ...                     ...
# 22539               0       0    0  ...                    0.72
# 22540               0       0    0  ...                    1.00
# 22541               0       0    2  ...                    1.00
# 22542               0       0    0  ...                    0.99
# 22543               0       0    0  ...                    0.08
#
#        dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                        0.06                         0.00
# 1                        0.06                         0.00
# 2                        0.04                         0.61
# 3                        0.00                         1.00
# 4                        0.17                         0.03
# ...                       ...                          ...
# 22539                    0.06                         0.01
# 22540                    0.00                         0.01
# 22541                    0.00                         0.00
# 22542                    0.01                         0.00
# 22543                    0.03                         0.00
#
#        dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  0.00
# 2                             0.02                  0.00
# 3                             0.28                  0.00
# 4                             0.02                  0.00
# ...                            ...                   ...
# 22539                         0.01                  0.01
# 22540                         0.01                  0.01
# 22541                         0.00                  0.00
# 22542                         0.00                  0.00
# 22543                         0.00                  0.00
#
#        dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                           0.0                  1.00
# 1                           0.0                  1.00
# 2                           0.0                  0.00
# 3                           0.0                  0.00
# 4                           0.0                  0.83
# ...                         ...                   ...
# 22539                       0.0                  0.00
# 22540                       0.0                  0.00
# 22541                       0.0                  0.07
# 22542                       0.0                  0.00
# 22543                       0.0                  0.44
#
#        dst_host_srv_rerror_rate    label  difficulty_level
# 0                          1.00  neptune                21
# 1                          1.00  neptune                21
# 2                          0.00   normal                21
# 3                          0.00    saint                15
# 4                          0.71    mscan                11
# ...                         ...      ...               ...
# 22539                      0.00   normal                21
# 22540                      0.00   normal                21
# 22541                      0.07     back                15
# 22542                      0.00   normal                21
# 22543                      1.00    mscan                14
#
# [22544 rows x 43 columns]

# %%
# remove attribute 'difficulty_level'
data.drop(['difficulty_level'],axis=1,inplace=True)
data.shape
# Out:
# (22544, 42)

# %%
data.describe()
# Out:
#            duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  22544.000000  2.254400e+04  2.254400e+04  22544.000000    22544.000000
# mean     218.859076  1.039545e+04  2.056019e+03      0.000311        0.008428
# std     1407.176612  4.727864e+05  2.121930e+04      0.017619        0.142599
# min        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 25%        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 50%        0.000000  5.400000e+01  4.600000e+01      0.000000        0.000000
# 75%        0.000000  2.870000e+02  6.010000e+02      0.000000        0.000000
# max    57715.000000  6.282565e+07  1.345927e+06      1.000000        3.000000
#
#              urgent           hot  num_failed_logins     logged_in  \
# count  22544.000000  22544.000000       22544.000000  22544.000000
# mean       0.000710      0.105394           0.021647      0.442202
# std        0.036473      0.928428           0.150328      0.496659
# min        0.000000      0.000000           0.000000      0.000000
# 25%        0.000000      0.000000           0.000000      0.000000
# 50%        0.000000      0.000000           0.000000      0.000000
# 75%        0.000000      0.000000           0.000000      1.000000
# max        3.000000    101.000000           4.000000      1.000000
#
#        num_compromised  ...  dst_host_count  dst_host_srv_count  \
# count     22544.000000  ...    22544.000000        22544.000000
# mean          0.119899  ...      193.869411          140.750532
# std           7.269597  ...       94.035663          111.783972
# min           0.000000  ...        0.000000            0.000000
# 25%           0.000000  ...      121.000000           15.000000
# 50%           0.000000  ...      255.000000          168.000000
# 75%           0.000000  ...      255.000000          255.000000
# max         796.000000  ...      255.000000          255.000000
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# count            22544.000000            22544.000000
# mean                 0.608722                0.090540
# std                  0.435688                0.220717
# min                  0.000000                0.000000
# 25%                  0.070000                0.000000
# 50%                  0.920000                0.010000
# 75%                  1.000000                0.060000
# max                  1.000000                1.000000
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# count                 22544.000000                 22544.000000
# mean                      0.132261                     0.019638
# std                       0.306268                     0.085394
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.030000                     0.010000
# max                       1.000000                     1.000000
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# count          22544.000000              22544.000000          22544.000000
# mean               0.097814                  0.099426              0.233385
# std                0.273139                  0.281866              0.387229
# min                0.000000                  0.000000              0.000000
# 25%                0.000000                  0.000000              0.000000
# 50%                0.000000                  0.000000              0.000000
# 75%                0.000000                  0.000000              0.360000
# max                1.000000                  1.000000              1.000000
#
#        dst_host_srv_rerror_rate
# count              22544.000000
# mean                   0.226683
# std                    0.400875
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.170000
# max                    1.000000
#
# [8 rows x 38 columns]

# %%
# number of attack labels
data['label'].value_counts()
# Out:
# label
# normal             9711
# neptune            4657
# guess_passwd       1231
# mscan               996
# warezmaster         944
# apache2             737
# satan               735
# processtable        685
# smurf               665
# back                359
# snmpguess           331
# saint               319
# mailbomb            293
# snmpgetattack       178
# portsweep           157
# ipsweep             141
# httptunnel          133
# nmap                 73
# pod                  41
# buffer_overflow      20
# multihop             18
# named                17
# ps                   15
# sendmail             14
# rootkit              13
# xterm                13
# teardrop             12
# xlock                 9
# land                  7
# xsnoop                4
# ftp_write             3
# worm                  2
# loadmodule            2
# perl                  2
# sqlattack             2
# udpstorm              2
# phf                   2
# imap                  1
# Name: count, dtype: int64

# %%
# changing attack labels to their respective attack class
def change_label(df):
  df.label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)
  df.label.replace(['ftp_write','guess_passwd','httptunnel','imap','multihop','named','phf','sendmail',
       'snmpgetattack','snmpguess','spy','warezclient','warezmaster','xlock','xsnoop'],'R2L',inplace=True)
  df.label.replace(['ipsweep','mscan','nmap','portsweep','saint','satan'],'Probe',inplace=True)
  df.label.replace(['buffer_overflow','loadmodule','perl','ps','rootkit','sqlattack','xterm'],'U2R',inplace=True)

# %%
# calling change_label() function
change_label(data)
# Out:
# <ipython-input-105-38fbacafca28>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)

# %%
# distribution of attack classes
data.label.value_counts()
# Out:
# label
# normal    9711
# Dos       7460
# R2L       2885
# Probe     2421
# U2R         67
# Name: count, dtype: int64

# %%
# selecting numeric attributes columns from data
numeric_col = data.select_dtypes(include='number').columns

# %%
# using standard scaler for normalizing
std_scaler = StandardScaler()

def normalization(df, col):
  for i in col:
    arr = df[i]
    arr = np.array(arr)
    df[i] = std_scaler.fit_transform(arr.reshape(len(arr), 1))
  return df

# %%
# data before normalization
data.head()
# Out:
#    duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0         0           tcp   private   REJ          0          0     0
# 1         0           tcp   private   REJ          0          0     0
# 2         2           tcp  ftp_data    SF      12983          0     0
# 3         0          icmp     eco_i    SF         20          0     0
# 4         1           tcp    telnet  RSTO          0         15     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  10
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  86
# 3               0       0    0  ...                  57
# 4               0       0    0  ...                  86
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.04                    0.06
# 1                    0.00                    0.06
# 2                    0.61                    0.04
# 3                    1.00                    0.00
# 4                    0.31                    0.17
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.00                         0.00
# 1                         0.00                         0.00
# 2                         0.61                         0.02
# 3                         1.00                         0.28
# 4                         0.03                         0.02
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                   0.0                       0.0                  1.00
# 1                   0.0                       0.0                  1.00
# 2                   0.0                       0.0                  0.00
# 3                   0.0                       0.0                  0.00
# 4                   0.0                       0.0                  0.83
#
#    dst_host_srv_rerror_rate   label
# 0                      1.00     Dos
# 1                      1.00     Dos
# 2                      0.00  normal
# 3                      0.00   Probe
# 4                      0.71   Probe
#
# [5 rows x 42 columns]

# %%
# calling the normalization() function
data = normalization(data.copy(),numeric_col)

# %%
# data after normalization
data.head()
# Out:
#    duration protocol_type   service  flag  src_bytes  dst_bytes      land  \
# 0 -0.155534           tcp   private   REJ  -0.021988  -0.096896 -0.017624
# 1 -0.155534           tcp   private   REJ  -0.021988  -0.096896 -0.017624
# 2 -0.154113           tcp  ftp_data    SF   0.005473  -0.096896 -0.017624
# 3 -0.155534          icmp     eco_i    SF  -0.021946  -0.096896 -0.017624
# 4 -0.154823           tcp    telnet  RSTO  -0.021988  -0.096189 -0.017624
#
#    wrong_fragment    urgent       hot  ...  dst_host_srv_count  \
# 0       -0.059104 -0.019459 -0.113521  ...           -1.169697
# 1       -0.059104 -0.019459 -0.113521  ...           -1.250212
# 2       -0.059104 -0.019459 -0.113521  ...           -0.489800
# 3       -0.059104 -0.019459 -0.113521  ...           -0.749234
# 4       -0.059104 -0.019459 -0.113521  ...           -0.489800
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0               -1.305370               -0.138370
# 1               -1.397181               -0.138370
# 2                0.002934               -0.228985
# 3                0.898090               -0.410217
# 4               -0.685647                0.360018
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                    -0.431856                    -0.229980
# 1                    -0.431856                    -0.229980
# 2                     1.559906                     0.004234
# 3                     2.833328                     3.049016
# 4                    -0.333901                     0.004234
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0             -0.358118                  -0.35275              1.979791
# 1             -0.358118                  -0.35275              1.979791
# 2             -0.358118                  -0.35275             -0.602719
# 3             -0.358118                  -0.35275             -0.602719
# 4             -0.358118                  -0.35275              1.540764
#
#    dst_host_srv_rerror_rate   label
# 0                  1.929116     Dos
# 1                  1.929116     Dos
# 2                 -0.565483  normal
# 3                 -0.565483   Probe
# 4                  1.205682   Probe
#
# [5 rows x 42 columns]

# %%
# selecting categorical data attributes
cat_col = ['protocol_type','service','flag']

# %%
# creating a dataframe with only categorical attributes
categorical = data[cat_col]
categorical.head()
# Out:
#   protocol_type   service  flag
# 0           tcp   private   REJ
# 1           tcp   private   REJ
# 2           tcp  ftp_data    SF
# 3          icmp     eco_i    SF
# 4           tcp    telnet  RSTO

# %%
# one-hot-encoding categorical attributes using pandas.get_dummies() function
categorical = pd.get_dummies(categorical,columns=cat_col)
categorical.head()
# Out:
#    protocol_type_icmp  protocol_type_tcp  protocol_type_udp  service_IRC  \
# 0               False               True              False        False
# 1               False               True              False        False
# 2               False               True              False        False
# 3                True              False              False        False
# 4               False               True              False        False
#
#    service_X11  service_Z39_50  service_auth  service_bgp  service_courier  \
# 0        False           False         False        False            False
# 1        False           False         False        False            False
# 2        False           False         False        False            False
# 3        False           False         False        False            False
# 4        False           False         False        False            False
#
#    service_csnet_ns  ...  flag_REJ  flag_RSTO  flag_RSTOS0  flag_RSTR  \
# 0             False  ...      True      False        False      False
# 1             False  ...      True      False        False      False
# 2             False  ...     False      False        False      False
# 3             False  ...     False      False        False      False
# 4             False  ...     False       True        False      False
#
#    flag_S0  flag_S1  flag_S2  flag_S3  flag_SF  flag_SH
# 0    False    False    False    False    False    False
# 1    False    False    False    False    False    False
# 2    False    False    False    False     True    False
# 3    False    False    False    False     True    False
# 4    False    False    False    False    False    False
#
# [5 rows x 78 columns]

# %%
# changing attack labels into two categories 'normal' and 'abnormal'
bin_label = pd.DataFrame(data.label.map(lambda x:'normal' if x=='normal' else 'abnormal'))

# %%
# creating a dataframe with binary labels (normal,abnormal)
bin_data = data.copy()
bin_data['label'] = bin_label

# %%
# label encoding (0,1) binary labels (abnormal,normal)
le1 = preprocessing.LabelEncoder()
enc_label = bin_label.apply(le1.fit_transform)
bin_data['intrusion'] = enc_label

# %%
# dataset with binary labels and label encoded column
bin_data.head()
# Out:
#    duration protocol_type   service  flag  src_bytes  dst_bytes      land  \
# 0 -0.155534           tcp   private   REJ  -0.021988  -0.096896 -0.017624
# 1 -0.155534           tcp   private   REJ  -0.021988  -0.096896 -0.017624
# 2 -0.154113           tcp  ftp_data    SF   0.005473  -0.096896 -0.017624
# 3 -0.155534          icmp     eco_i    SF  -0.021946  -0.096896 -0.017624
# 4 -0.154823           tcp    telnet  RSTO  -0.021988  -0.096189 -0.017624
#
#    wrong_fragment    urgent       hot  ...  dst_host_same_srv_rate  \
# 0       -0.059104 -0.019459 -0.113521  ...               -1.305370
# 1       -0.059104 -0.019459 -0.113521  ...               -1.397181
# 2       -0.059104 -0.019459 -0.113521  ...                0.002934
# 3       -0.059104 -0.019459 -0.113521  ...                0.898090
# 4       -0.059104 -0.019459 -0.113521  ...               -0.685647
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0               -0.138370                    -0.431856
# 1               -0.138370                    -0.431856
# 2               -0.228985                     1.559906
# 3               -0.410217                     2.833328
# 4                0.360018                    -0.333901
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                    -0.229980             -0.358118
# 1                    -0.229980             -0.358118
# 2                     0.004234             -0.358118
# 3                     3.049016             -0.358118
# 4                     0.004234             -0.358118
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                  -0.35275              1.979791                  1.929116
# 1                  -0.35275              1.979791                  1.929116
# 2                  -0.35275             -0.602719                 -0.565483
# 3                  -0.35275             -0.602719                 -0.565483
# 4                  -0.35275              1.540764                  1.205682
#
#       label  intrusion
# 0  abnormal          0
# 1  abnormal          0
# 2    normal          1
# 3  abnormal          0
# 4  abnormal          0
#
# [5 rows x 43 columns]

# %%
# one-hot-encoding attack label
bin_data = pd.get_dummies(bin_data,columns=['label'],prefix="",prefix_sep="")
bin_data['label'] = bin_label
bin_data
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes      land  \
# 0     -0.155534           tcp   private   REJ  -0.021988  -0.096896 -0.017624
# 1     -0.155534           tcp   private   REJ  -0.021988  -0.096896 -0.017624
# 2     -0.154113           tcp  ftp_data    SF   0.005473  -0.096896 -0.017624
# 3     -0.155534          icmp     eco_i    SF  -0.021946  -0.096896 -0.017624
# 4     -0.154823           tcp    telnet  RSTO  -0.021988  -0.096189 -0.017624
# ...         ...           ...       ...   ...        ...        ...       ...
# 22539 -0.155534           tcp      smtp    SF  -0.020309  -0.081202 -0.017624
# 22540 -0.155534           tcp      http    SF  -0.021318  -0.052690 -0.017624
# 22541 -0.155534           tcp      http    SF   0.093373   0.294926 -0.017624
# 22542 -0.155534           udp  domain_u    SF  -0.021899  -0.094917 -0.017624
# 22543 -0.155534           tcp    sunrpc   REJ  -0.021988  -0.096896 -0.017624
#
#        wrong_fragment    urgent       hot  ...  dst_host_same_src_port_rate  \
# 0           -0.059104 -0.019459 -0.113521  ...                    -0.431856
# 1           -0.059104 -0.019459 -0.113521  ...                    -0.431856
# 2           -0.059104 -0.019459 -0.113521  ...                     1.559906
# 3           -0.059104 -0.019459 -0.113521  ...                     2.833328
# 4           -0.059104 -0.019459 -0.113521  ...                    -0.333901
# ...               ...       ...       ...  ...                          ...
# 22539       -0.059104 -0.019459 -0.113521  ...                    -0.399204
# 22540       -0.059104 -0.019459 -0.113521  ...                    -0.399204
# 22541       -0.059104 -0.019459  2.040705  ...                    -0.431856
# 22542       -0.059104 -0.019459 -0.113521  ...                    -0.431856
# 22543       -0.059104 -0.019459 -0.113521  ...                    -0.431856
#
#        dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                        -0.229980             -0.358118
# 1                        -0.229980             -0.358118
# 2                         0.004234             -0.358118
# 3                         3.049016             -0.358118
# 4                         0.004234             -0.358118
# ...                            ...                   ...
# 22539                    -0.112873             -0.321505
# 22540                    -0.112873             -0.321505
# 22541                    -0.229980             -0.358118
# 22542                    -0.229980             -0.358118
# 22543                    -0.229980             -0.358118
#
#        dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      -0.35275              1.979791
# 1                      -0.35275              1.979791
# 2                      -0.35275             -0.602719
# 3                      -0.35275             -0.602719
# 4                      -0.35275              1.540764
# ...                         ...                   ...
# 22539                  -0.35275             -0.602719
# 22540                  -0.35275             -0.602719
# 22541                  -0.35275             -0.421943
# 22542                  -0.35275             -0.602719
# 22543                  -0.35275              0.533585
#
#        dst_host_srv_rerror_rate  intrusion  abnormal  normal     label
# 0                      1.929116          0      True   False  abnormal
# 1                      1.929116          0      True   False  abnormal
# 2                     -0.565483          1     False    True    normal
# 3                     -0.565483          0      True   False  abnormal
# 4                      1.205682          0      True   False  abnormal
# ...                         ...        ...       ...     ...       ...
# 22539                 -0.565483          1     False    True    normal
# 22540                 -0.565483          1     False    True    normal
# 22541                 -0.390861          0      True   False  abnormal
# 22542                 -0.565483          1     False    True    normal
# 22543                  1.929116          0      True   False  abnormal
#
# [22544 rows x 45 columns]

# %%
# pie chart distribution of normal and abnormal labels
plt.figure(figsize=(8,8))
plt.pie(bin_data.label.value_counts(),labels=bin_data.label.unique(),autopct='%0.2f%%')
plt.title("Pie chart distribution of normal and abnormal labels")
plt.legend()
plt.show()

# %%
# creating a dataframe with only numeric attributes of binary class dataset and encoded label attribute
numeric_bin = bin_data[numeric_col]
numeric_bin['intrusion'] = bin_data['intrusion']
# Out:
# <ipython-input-121-1e82c1581057>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_bin['intrusion'] = bin_data['intrusion']

# %%
# finding the attributes which have more than 0.5 correlation with encoded attack label attribute
corr= numeric_bin.corr()
corr_y = abs(corr['intrusion'])
highest_corr = corr_y[corr_y >0.5]
highest_corr.sort_values(ascending=True)
# Out:
# same_srv_rate             0.510634
# logged_in                 0.551159
# dst_host_same_srv_rate    0.575526
# dst_host_srv_count        0.593344
# intrusion                 1.000000
# Name: intrusion, dtype: float64

# %%
# selecting attributes found by using pearson correlation coefficient
numeric_bin = bin_data[['count','srv_serror_rate','serror_rate','dst_host_serror_rate','dst_host_srv_serror_rate',
                         'logged_in','dst_host_same_srv_rate','dst_host_srv_count','same_srv_rate']]

# %%
# joining the selected attribute with the one-hot-encoded categorical dataframe
numeric_bin = numeric_bin.join(categorical)
# then joining encoded, one-hot-encoded, and original attack label attribute
bin_data = numeric_bin.join(bin_data[['intrusion','abnormal','normal','label']])

# %%
# saving final dataset to disk
bin_data.to_csv("bin_data.csv")
# final dataset for binary classification
bin_data
# Out:
#           count  srv_serror_rate  serror_rate  dst_host_serror_rate  \
# 0      1.166764        -0.347390    -0.348468             -0.358118
# 1      0.443234        -0.347390    -0.348468             -0.358118
# 2     -0.607053        -0.347390    -0.348468             -0.358118
# 3     -0.607053        -0.347390    -0.348468             -0.358118
# 4     -0.607053         0.054856    -0.348468             -0.358118
# ...         ...              ...          ...                   ...
# 22539 -0.607053        -0.347390    -0.348468             -0.321505
# 22540 -0.599273        -0.347390    -0.348468             -0.321505
# 22541 -0.575933        -0.347390    -0.348468             -0.358118
# 22542 -0.583713        -0.347390    -0.348468             -0.358118
# 22543 -0.583713        -0.347390    -0.348468             -0.358118
#
#        dst_host_srv_serror_rate  logged_in  dst_host_same_srv_rate  \
# 0                      -0.35275  -0.890373               -1.305370
# 1                      -0.35275  -0.890373               -1.397181
# 2                      -0.35275  -0.890373                0.002934
# 3                      -0.35275  -0.890373                0.898090
# 4                      -0.35275  -0.890373               -0.685647
# ...                         ...        ...                     ...
# 22539                  -0.35275   1.123125                0.255414
# 22540                  -0.35275   1.123125                0.898090
# 22541                  -0.35275   1.123125                0.898090
# 22542                  -0.35275  -0.890373                0.875137
# 22543                  -0.35275  -0.890373               -1.213559
#
#        dst_host_srv_count  same_srv_rate  protocol_type_icmp  ...  flag_S0  \
# 0               -1.169697      -1.697859               False  ...    False
# 1               -1.250212      -1.770589               False  ...    False
# 2               -0.489800       0.629488               False  ...    False
# 3               -0.749234       0.629488                True  ...    False
# 4               -0.489800       0.629488               False  ...    False
# ...                   ...            ...                 ...  ...      ...
# 22539            0.002232       0.629488               False  ...    False
# 22540            1.022079       0.629488               False  ...    False
# 22541            1.022079       0.629488               False  ...    False
# 22542            0.995240       0.629488               False  ...    False
# 22543           -1.071291      -1.188752               False  ...    False
#
#        flag_S1  flag_S2  flag_S3  flag_SF  flag_SH  intrusion  abnormal  \
# 0        False    False    False    False    False          0      True
# 1        False    False    False    False    False          0      True
# 2        False    False    False     True    False          1     False
# 3        False    False    False     True    False          0      True
# 4        False    False    False    False    False          0      True
# ...        ...      ...      ...      ...      ...        ...       ...
# 22539    False    False    False     True    False          1     False
# 22540    False    False    False     True    False          1     False
# 22541    False    False    False     True    False          0      True
# 22542    False    False    False     True    False          1     False
# 22543    False    False    False    False    False          0      True
#
#        normal     label
# 0       False  abnormal
# 1       False  abnormal
# 2        True    normal
# 3       False  abnormal
# 4       False  abnormal
# ...       ...       ...
# 22539    True    normal
# 22540    True    normal
# 22541   False  abnormal
# 22542    True    normal
# 22543   False  abnormal
#
# [22544 rows x 91 columns]

# %%
X = bin_data.iloc[:,0:93].values # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = bin_data[['intrusion']].values # target attribute

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
mlp = Sequential() # creating model

# adding input layer and first layer with 50 neurons
mlp.add(Dense(units=50, input_dim=X_train.shape[1], activation='relu'))
# output layer with sigmoid activation
mlp.add(Dense(units=1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
mlp.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 50)                  │           4,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,651 (18.17 KB)
#  Trainable params: 4,651 (18.17 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
X = bin_data.iloc[:,0:93].values # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = bin_data[['intrusion']].values # target attribute
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
from sklearn.preprocessing import LabelEncoder

# Convert DataFrame to avoid modifying original data
bin_data_encoded = bin_data.copy()

# Identify categorical columns
categorical_cols = bin_data_encoded.select_dtypes(include=['object']).columns

# Apply Label Encoding to each categorical column
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    bin_data_encoded[col] = le.fit_transform(bin_data_encoded[col])
    label_encoders[col] = le  # Save encoders for future inverse transformation

# Now extract feature matrix and target variable
X = bin_data_encoded.iloc[:, 0:93].values  # Features
Y = bin_data_encoded[['intrusion']].values  # Target

# Continue with train-test split and conversion

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Convert DataFrame to avoid modifying original data
bin_data_encoded = bin_data.copy()

# Identify categorical columns
categorical_cols = bin_data_encoded.select_dtypes(include=['object']).columns

# Apply Label Encoding to each categorical column
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    bin_data_encoded[col] = le.fit_transform(bin_data_encoded[col])
    label_encoders[col] = le  # Save encoders for future inverse transformation

# Now extract feature matrix and target variable
X = bin_data_encoded.iloc[:, 0:93].values  # Features
Y = bin_data_encoded[['intrusion']].values  # Target

# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# Convert training and testing data to float32
X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)
y_train = y_train.astype(np.float32)
y_test = y_test.astype(np.float32)

# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# training the model on training dataset
history = mlp.fit(X_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)

X_test = np.nan_to_num(X_test)  # Replace NaN and Infinity with finite values
y_test = np.nan_to_num(y_test)
test_results = mlp.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}')
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.3435 - loss: 0.7220 - val_accuracy: 0.7079 - val_loss: 0.6759
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7139 - loss: 0.6692 - val_accuracy: 0.7694 - val_loss: 0.6279
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7791 - loss: 0.6215 - val_accuracy: 0.8152 - val_loss: 0.5842
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8426 - loss: 0.5780 - val_accuracy: 0.9586 - val_loss: 0.5446
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9626 - loss: 0.5386 - val_accuracy: 0.9704 - val_loss: 0.5088
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9713 - loss: 0.5028 - val_accuracy: 0.9728 - val_loss: 0.4766
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9742 - loss: 0.4709 - val_accuracy: 0.9740 - val_loss: 0.4472
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9752 - loss: 0.4412 - val_accuracy: 0.9752 - val_loss: 0.4207
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9772 - loss: 0.4144 - val_accuracy: 0.9763 - val_loss: 0.3969
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9778 - loss: 0.3907 - val_accuracy: 0.9775 - val_loss: 0.3757
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9785 - loss: 0.3699 - val_accuracy: 0.9775 - val_loss: 0.3561
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9791 - loss: 0.3501 - val_accuracy: 0.9784 - val_loss: 0.3379
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9803 - loss: 0.3314 - val_accuracy: 0.9805 - val_loss: 0.3209
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9817 - loss: 0.3148 - val_accuracy: 0.9823 - val_loss: 0.3049
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9833 - loss: 0.2978 - val_accuracy: 0.9837 - val_loss: 0.2895
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9844 - loss: 0.2830 - val_accuracy: 0.9843 - val_loss: 0.2749
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9871 - loss: 0.2684 - val_accuracy: 0.9849 - val_loss: 0.2610
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9871 - loss: 0.2544 - val_accuracy: 0.9858 - val_loss: 0.2477
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9873 - loss: 0.2413 - val_accuracy: 0.9861 - val_loss: 0.2350
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9872 - loss: 0.2286 - val_accuracy: 0.9867 - val_loss: 0.2226
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9889 - loss: 0.2154 - val_accuracy: 0.9876 - val_loss: 0.2108
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9893 - loss: 0.2046 - val_accuracy: 0.9894 - val_loss: 0.1997
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9901 - loss: 0.1931 - val_accuracy: 0.9911 - val_loss: 0.1891
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9917 - loss: 0.1824 - val_accuracy: 0.9911 - val_loss: 0.1792
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9914 - loss: 0.1733 - val_accuracy: 0.9917 - val_loss: 0.1698
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9925 - loss: 0.1637 - val_accuracy: 0.9920 - val_loss: 0.1609
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9924 - loss: 0.1554 - val_accuracy: 0.9923 - val_loss: 0.1525
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9930 - loss: 0.1468 - val_accuracy: 0.9926 - val_loss: 0.1444
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9929 - loss: 0.1395 - val_accuracy: 0.9932 - val_loss: 0.1368
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9932 - loss: 0.1320 - val_accuracy: 0.9932 - val_loss: 0.1296
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9940 - loss: 0.1245 - val_accuracy: 0.9941 - val_loss: 0.1227
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9946 - loss: 0.1186 - val_accuracy: 0.9947 - val_loss: 0.1162
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9952 - loss: 0.1112 - val_accuracy: 0.9950 - val_loss: 0.1101
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9960 - loss: 0.1063 - val_accuracy: 0.9962 - val_loss: 0.1044
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9967 - loss: 0.1001 - val_accuracy: 0.9976 - val_loss: 0.0989
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9977 - loss: 0.0950 - val_accuracy: 0.9982 - val_loss: 0.0938
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9983 - loss: 0.0905 - val_accuracy: 0.9982 - val_loss: 0.0890
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9983 - loss: 0.0856 - val_accuracy: 0.9982 - val_loss: 0.0844
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9985 - loss: 0.0804 - val_accuracy: 0.9985 - val_loss: 0.0801
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9989 - loss: 0.0768 - val_accuracy: 0.9985 - val_loss: 0.0761
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9989 - loss: 0.0727 - val_accuracy: 0.9985 - val_loss: 0.0723
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9987 - loss: 0.0692 - val_accuracy: 0.9985 - val_loss: 0.0687
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9989 - loss: 0.0658 - val_accuracy: 0.9985 - val_loss: 0.0654
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9989 - loss: 0.0626 - val_accuracy: 0.9994 - val_loss: 0.0623
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9990 - loss: 0.0597 - val_accuracy: 0.9994 - val_loss: 0.0593
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9990 - loss: 0.0567 - val_accuracy: 0.9994 - val_loss: 0.0565
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9995 - loss: 0.0543 - val_accuracy: 0.9997 - val_loss: 0.0539
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9994 - loss: 0.0521 - val_accuracy: 0.9997 - val_loss: 0.0514
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9993 - loss: 0.0495 - val_accuracy: 0.9997 - val_loss: 0.0491
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9996 - loss: 0.0473 - val_accuracy: 0.9997 - val_loss: 0.0469
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9998 - loss: 0.0445 - val_accuracy: 0.9997 - val_loss: 0.0448
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9997 - loss: 0.0432 - val_accuracy: 0.9997 - val_loss: 0.0428
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9997 - loss: 0.0411 - val_accuracy: 0.9997 - val_loss: 0.0410
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9997 - loss: 0.0395 - val_accuracy: 0.9997 - val_loss: 0.0392
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9997 - loss: 0.0376 - val_accuracy: 0.9997 - val_loss: 0.0375
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9998 - loss: 0.0356 - val_accuracy: 0.9997 - val_loss: 0.0359
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9998 - loss: 0.0345 - val_accuracy: 0.9997 - val_loss: 0.0344
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9998 - loss: 0.0330 - val_accuracy: 0.9997 - val_loss: 0.0330
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9998 - loss: 0.0318 - val_accuracy: 0.9997 - val_loss: 0.0316
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9999 - loss: 0.0302 - val_accuracy: 0.9997 - val_loss: 0.0304
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9998 - loss: 0.0290 - val_accuracy: 0.9997 - val_loss: 0.0292
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9998 - loss: 0.0280 - val_accuracy: 0.9997 - val_loss: 0.0281
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9999 - loss: 0.0268 - val_accuracy: 0.9997 - val_loss: 0.0270
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9999 - loss: 0.0257 - val_accuracy: 0.9997 - val_loss: 0.0261
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9998 - loss: 0.0249 - val_accuracy: 0.9997 - val_loss: 0.0251
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9998 - loss: 0.0241 - val_accuracy: 0.9997 - val_loss: 0.0242
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9999 - loss: 0.0233 - val_accuracy: 0.9997 - val_loss: 0.0234
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9998 - loss: 0.0224 - val_accuracy: 0.9997 - val_loss: 0.0226
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9999 - loss: 0.0215 - val_accuracy: 0.9997 - val_loss: 0.0218
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9999 - loss: 0.0208 - val_accuracy: 0.9997 - val_loss: 0.0211
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9999 - loss: 0.0200 - val_accuracy: 0.9997 - val_loss: 0.0204
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9998 - loss: 0.0193 - val_accuracy: 0.9997 - val_loss: 0.0198
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9998 - loss: 0.0190 - val_accuracy: 0.9997 - val_loss: 0.0191
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9999 - loss: 0.0182 - val_accuracy: 0.9997 - val_loss: 0.0185
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9998 - loss: 0.0177 - val_accuracy: 0.9997 - val_loss: 0.0179
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9998 - loss: 0.0173 - val_accuracy: 0.9997 - val_loss: 0.0174
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9998 - loss: 0.0166 - val_accuracy: 0.9997 - val_loss: 0.0169
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9999 - loss: 0.0162 - val_accuracy: 0.9997 - val_loss: 0.0164
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9999 - loss: 0.0156 - val_accuracy: 0.9997 - val_loss: 0.0159
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9999 - loss: 0.0153 - val_accuracy: 0.9997 - val_loss: 0.0154
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9999 - loss: 0.0147 - val_accuracy: 0.9997 - val_loss: 0.0150
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9999 - loss: 0.0143 - val_accuracy: 0.9997 - val_loss: 0.0146
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9999 - loss: 0.0139 - val_accuracy: 0.9997 - val_loss: 0.0142
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9999 - loss: 0.0135 - val_accuracy: 0.9997 - val_loss: 0.0138
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9999 - loss: 0.0132 - val_accuracy: 0.9997 - val_loss: 0.0134
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9999 - loss: 0.0128 - val_accuracy: 0.9997 - val_loss: 0.0130
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9999 - loss: 0.0125 - val_accuracy: 0.9997 - val_loss: 0.0127
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9999 - loss: 0.0121 - val_accuracy: 0.9997 - val_loss: 0.0124
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 0.0120
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9999 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9999 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9999 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 0.0109
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 1.0000 - val_loss: 0.0106
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 0.0101
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0096
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0092
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0087
# Test results - Loss: 0.008812787011265755 - Accuracy: 99.98225569725037

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset

X_test = np.nan_to_num(X_test)  # Replace NaN and Infinity with finite values
y_test = np.nan_to_num(y_test)
X_test = X_test.astype(np.float32)  # Convert to float32
y_test = y_test.astype(np.float32)
test_results = mlp.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}')
# Out:
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 0.0087
# Test results - Loss: 0.008812787011265755 - Accuracy: 99.98225569725037

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')

plt.show()

# %%
from sklearn.metrics import roc_curve, auc as roc_auc_score
import matplotlib.pyplot as plt
y_pred = mlp.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc = roc_auc_score(fpr, tpr)
# Out:
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Keras (area = {:.3f})'.format(auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')

plt.show()

# %%
pred = mlp.predict(X_test)
y_classes = (mlp.predict(X_test)>0.5).astype('int32')
# Out:
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
print("Recall Score - ",recall_score(y_test,y_classes))
print("F1 Score - ",f1_score(y_test,y_classes))
print("Precision Score - ",precision_score(y_test,y_classes))
# Out:
# Recall Score -  0.9995869475423379
# F1 Score -  0.999793431109275
# Precision Score -  1.0
